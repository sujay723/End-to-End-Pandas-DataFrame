# %%
import pandas as pd

# %% [markdown]
# # Key Data Structure in pandas
# * Series(1D)
# * DataFrame(2D)

# %%
s = pd.Series([1,2,3,4,5,6] , index=['a','b','c' ,'d' ,'e' ,'f'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
df = pd.DataFrame({"Name":["Sujay", "Harry", "Rohan", "Shubham"], "Marks":[99,30,50,80]})

# %%
df
# Out:
#       Name  Marks
# 0    Sujay     99
# 1    Harry     30
# 2    Rohan     50
# 3  Shubham     80

# %%
df=pd.read_csv("csv-files-sample4.csv")

# %%
df
# Out:
#      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.head(10)
# Out:
#    Game Number   "Game Length"
# 0            1            30.0
# 1            2            29.0
# 2            3             NaN
# 3            4             NaN
# 4            5            24.0
# 5            6             NaN
# 6            7            28.0
# 7            8             NaN
# 8            9            42.0
# 9           10            23.0

# %%
df.tail()
# Out:
#      Game Number   "Game Length"
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0

# %%
df.describe()
# Out:
#        Game Number   "Game Length"
# count  1000.000000      996.000000
# mean    500.500000       35.359438
# std     288.819436       23.307111
# min       1.000000        7.000000
# 25%     250.750000       19.000000
# 50%     500.500000       30.000000
# 75%     750.250000       45.000000
# max    1000.000000      197.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Game Number     1000 non-null   int64
#  1    "Game Length"  996 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 15.8 KB

# %% [markdown]
# # Data Selection

# %%
df["Game Number"]
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: Game Number, Length: 1000, dtype: int64

# %%
df2 = pd.read_csv("annual-enterprise-survey-2023-financial-year-provisional-size-bands.csv")

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df2[["year","variable" ]]
# Out:
#        year                                         variable
# 0      2011                                    Activity unit
# 1      2011                           Rolling mean employees
# 2      2011                          Salaries and wages paid
# 3      2011  Sales, government funding, grants and subsidies
# 4      2011                                     Total income
# ...     ...                                              ...
# 20119  2023                                     Total income
# 20120  2023                                Total expenditure
# 20121  2023                      Operating profit before tax
# 20122  2023                                     Total assets
# 20123  2023                            Fixed tangible assets
#
# [20124 rows x 2 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20124 entries, 0 to 20123
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  20124 non-null  int64
#  1   industry_code_ANZSIC  20124 non-null  object
#  2   industry_name_ANZSIC  20124 non-null  object
#  3   rme_size_grp          20124 non-null  object
#  4   variable              20124 non-null  object
#  5   value                 20124 non-null  object
#  6   unit                  20124 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.1+ MB

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.iloc[0]
# Out:
# year                                                 2011
# industry_code_ANZSIC                                    A
# industry_name_ANZSIC    Agriculture, Forestry and Fishing
# rme_size_grp                                          a_0
# variable                                    Activity unit
# value                                               46134
# unit                                                COUNT
# Name: 0, dtype: object

# %%
df2.iloc[3]
# Out:
# year                                                               2011
# industry_code_ANZSIC                                                  A
# industry_name_ANZSIC                  Agriculture, Forestry and Fishing
# rme_size_grp                                                        a_0
# variable                Sales, government funding, grants and subsidies
# value                                                              8187
# unit                                                  DOLLARS(millions)
# zeros                                                                 0
# zeros + 1                                                       4044121
# Name: 3, dtype: object

# %%
df2
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df3 = pd.read_csv("Aannual-enterprise-survey-2023-financial-year-provisional-size-bands - Copy.csv")

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df3.value_counts().head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df3
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0         NaN                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df3.head(10)
# Out:
#      year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0     NaN                    A  Agriculture, Forestry and Fishing
# 1  2011.0                    A  Agriculture, Forestry and Fishing
# 2  2011.0                    A  Agriculture, Forestry and Fishing
# 3  2011.0                    A  Agriculture, Forestry and Fishing
# 4  2011.0                    A  Agriculture, Forestry and Fishing
# 5     NaN                    A  Agriculture, Forestry and Fishing
# 6  2011.0                    A  Agriculture, Forestry and Fishing
# 7  2011.0                  NaN  Agriculture, Forestry and Fishing
# 8  2011.0                    A                                NaN
# 9  2011.0                    A  Agriculture, Forestry and Fishing
#
#   rme_size_grp                                         variable  value  \
# 0          a_0                                    Activity unit  46134
# 1          a_0                           Rolling mean employees      0
# ...

# %%
df3.dropna()
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# 6      2011.0                    A  Agriculture, Forestry and Fishing
# 9      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                     variable    value               unit
# ...

# %%
df3.fillna(0, inplace=True)

# %%
df3
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0         0.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df3.fillna(0)
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0         0.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df2.fillna(0)
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df2
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df3
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0         0.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df3.rename(columns={"year":"YR"})
# Out:
#            YR industry_code_ANZSIC               industry_name_ANZSIC  \
# 0         0.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df3
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0         0.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df3.describe()
# Out:
#                year
# count  20124.000000
# mean    2016.800139
# std       20.452368
# min        0.000000
# 25%     2014.000000
# 50%     2017.000000
# 75%     2020.000000
# max     2023.000000

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20124 entries, 0 to 20123
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  20124 non-null  float64
#  1   industry_code_ANZSIC  20124 non-null  object
#  2   industry_name_ANZSIC  20124 non-null  object
#  3   rme_size_grp          20124 non-null  object
#  4   variable              20124 non-null  object
#  5   value                 20124 non-null  object
#  6   unit                  20124 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.1+ MB

# %%
df3['year'] = df3['year'].astype(float)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20124 entries, 0 to 20123
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  20124 non-null  float64
#  1   industry_code_ANZSIC  20124 non-null  object
#  2   industry_name_ANZSIC  20124 non-null  object
#  3   rme_size_grp          20124 non-null  object
#  4   variable              20124 non-null  object
#  5   value                 20124 non-null  object
#  6   unit                  20124 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.1+ MB

# %%
df3
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0         0.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df3["year"] [2]
# Out:
# np.float64(2011.0)

# %%
len(df2)
# Out:
# 20124

# %%
df2["zeros"] = [0 for i in range(len(df2))]

# %%
df2
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
def fx(a):
    return a + 1
df2["zeros + 1"] = df2["zeros"] .apply(fx)

# %%
df2
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
def fx(a):
    return a *a
df2["zeros + 1"] = df2["year"] .apply(fx)

# %%
df2
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %% [markdown]
# # Make New csv File

# %%
df2.to_csv("data/export.csv")

# %%
df2.to_csv("data/export.csv" , index=False)

# %% [markdown]
# # Marging

# %%
import pandas as pd

# %%
df4=pd.DataFrame({

    "name": ["Harry" , "Sujay" , "Rohan" , "Shivam" , "Divya" , "Aparna" , "Khushi"],
    "marks": [60, 90, 80, 70, 45, 68, 45]

})

# %%
df4
# Out:
#      name  marks
# 0   Harry     60
# 1   Sujay     90
# 2   Rohan     80
# 3  Shivam     70
# 4   Divya     45
# 5  Aparna     68
# 6  Khushi     45

# %%
df5 = pd.DataFrame({

    "name": ["Akash" , "Akasa" , "alka" , "Priyanka"],
    "marks": [86, 100, 95, 70]

})

# %%
df5
# Out:
#        name  marks
# 0     Akash     86
# 1     Akasa    100
# 2      alka     95
# 3  Priyanka     70

# %%
pd.concat([df4,df5])
# Out:
#        name  marks
# 0     Harry     60
# 1     Sujay     90
# 2     Rohan     80
# 3    Shivam     70
# 4     Divya     45
# 5    Aparna     68
# 6    Khushi     45
# 0     Akash     86
# 1     Akasa    100
# 2      alka     95
# 3  Priyanka     70

# %%
df6 = pd.DataFrame({
    "name":["Akash" , "Priyanka"],
    "marks": [100,53]
})

# %%
df6
# Out:
#        name  marks
# 0     Akash    100
# 1  Priyanka     53

# %%
df7 = pd.DataFrame({
    "name":["Akash" , "Priyanka"],
    "roll": [1244,1245]
})

# %%
df7
# Out:
#        name  roll
# 0     Akash  1244
# 1  Priyanka  1245

# %%
pd.merge(df6 , df7 , on="name")
# Out:
#        name  marks  roll
# 0     Akash    100  1244
# 1  Priyanka     53  1245

# %%
df8 = pd.DataFrame({
    "name":["Akash" , "Priyanka"],
    "marks": [100,53]
})

# %%
df8
# Out:
#        name  marks
# 0     Akash    100
# 1  Priyanka     53

# %%
df9 = pd.DataFrame({
    "name":["Akash" , "Priyanka", "Sujay"],
    "roll": [1244,1245,1256]
})

# %%
df9
# Out:
#        name  roll
# 0     Akash  1244
# 1  Priyanka  1245
# 2     Sujay  1256

# %%
pd.merge(df8,df9, on="name")
# Out:
#        name  marks  roll
# 0     Akash    100  1244
# 1  Priyanka     53  1245
