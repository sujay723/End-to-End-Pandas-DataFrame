# %%
import pandas as pd

# %%
sub = pd.read_csv("csv-files-sample4.csv")

# %%
sub.head(5)
# Out:
#    Game Number   "Game Length"
# 0            1            30.0
# 1            2            29.0
# 2            3             NaN
# 3            4             NaN
# 4            5            24.0

# %%
sub.tail(7)
# Out:
#      Game Number   "Game Length"
# 993          994            32.0
# 994          995            93.0
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0

# %%
type(sub)
# Out:
# pandas.core.frame.DataFrame

# %%
sub
# Out:
#      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]

# %%
import sqlite3 as sql

# %%
sun = pd.read_csv("customers.csv")

# %%
sub
# Out:
#      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]

# %%
sub.head(5)
# Out:
#    Game Number   "Game Length"
# 0            1            30.0
# 1            2            29.0
# 2            3             NaN
# 3            4             NaN
# 4            5            24.0

# %%
sun
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
sun.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
sun.tail(5)
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
sun.notnull
# Out:
# <bound method DataFrame.notnull of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
sun.notna
# Out:
# <bound method DataFrame.notna of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
sun
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
sun.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
sun.notnull
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sun.notnull
#
# NameError: name 'sun' is not defined

# %%
sun.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sun.head()
#
# NameError: name 'sun' is not defined

# %%
import pandas as pd

# %%
sub = pd.read_csv("customers.csv")

# %%
sub
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
sub.head(10)
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# ...

# %%
sub.notnull
# Out:
# <bound method DataFrame.notnull of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
sub.fillna
# Out:
# <bound method NDFrame.fillna of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
sun = pd.read_csv("csv-files-sample4.csv")

# %%
sun
# Out:
#      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]

# %%
sun.head(10)
# Out:
#    Game Number   "Game Length"
# 0            1            30.0
# 1            2            29.0
# 2            3             NaN
# 3            4             NaN
# 4            5            24.0
# 5            6             NaN
# 6            7            28.0
# 7            8             NaN
# 8            9            42.0
# 9           10            23.0

# %%
sun.notna
# Out:
# <bound method DataFrame.notna of      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]>

# %%
sun.sort_values
# Out:
# <bound method DataFrame.sort_values of      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]>

# %%
sun.count()
# Out:
# Game Number       1000
#  "Game Length"     996
# dtype: int64

# %%
sun.sum
# Out:
# <bound method DataFrame.sum of      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]>

# %%
sun.describe()
# Out:
#        Game Number   "Game Length"
# count  1000.000000      996.000000
# mean    500.500000       35.359438
# std     288.819436       23.307111
# min       1.000000        7.000000
# 25%     250.750000       19.000000
# 50%     500.500000       30.000000
# 75%     750.250000       45.000000
# max    1000.000000      197.000000

# %%
sun
# Out:
#      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]

# %%
s = pd.read_csv("customers.csv")

# %%
s
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
s.head(10)
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# ...

# %%
s.tail(10)
# Out:
#     Index      Customer Id First Name Last Name                      Company  \
# 90     91  5ef6d3eefdD43bE       Nina    Chavez                Byrd-Campbell
# 91     92  98b3aeDcC3B9FF3      Shane     Foley                   Rocha-Hart
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers                Lamb-Peterson
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young      Lee, Lucero and Johnson
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas  Newton, Petersen and Mathis
# 95     96  cb8E23e48d22Eae       Karl     Greer                    Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson        Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra                Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer           Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes           Le, Nash and Cross
#
#                 City          Country                Phone 1  \
# ...

# %%
s.fillna
# Out:
# <bound method NDFrame.fillna of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
s.notna
# Out:
# <bound method DataFrame.notna of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
pd = pd.read_csv("csv-files-sample4.csv")

# %%
pd
# Out:
#      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]

# %%
pd.head(10)
# Out:
#    Game Number   "Game Length"
# 0            1            30.0
# 1            2            29.0
# 2            3             NaN
# 3            4             NaN
# 4            5            24.0
# 5            6             NaN
# 6            7            28.0
# 7            8             NaN
# 8            9            42.0
# 9           10            23.0

# %%
pd.tail(10)
# Out:
#      Game Number   "Game Length"
# 990          991            24.0
# 991          992            27.0
# 992          993            28.0
# 993          994            32.0
# 994          995            93.0
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0

# %%
pd.fillna
# Out:
# <bound method NDFrame.fillna of      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]>

# %%
pd.notna
# Out:
# <bound method DataFrame.notna of      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]>

# %%
pd.info
# Out:
# <bound method DataFrame.info of      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]>

# %%
pd.describe
# Out:
# <bound method NDFrame.describe of      Game Number   "Game Length"
# 0              1            30.0
# 1              2            29.0
# 2              3             NaN
# 3              4             NaN
# 4              5            24.0
# ..           ...             ...
# 995          996            24.0
# 996          997            21.0
# 997          998            47.0
# 998          999            30.0
# 999         1000            12.0
#
# [1000 rows x 2 columns]>

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 2.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.1 MB 2.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.1 MB 3.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 4.2 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 11.2 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
pd.plot()
# Out:
# <Axes: >

# %%
s.plot()
# Out:
# <Axes: >

# %%
pd.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='Game Number, "Game Length"'>

# %%
s.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='Index,Customer Id,First Name,Last Name,Company,City,Country,Phone 1,Phone 2,Email,Subscription Date,Website'>

# %%
pd.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='Game Number, "Game Length"'>

# %%
pd.value_counts().head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
s.value_counts().head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
s.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='Index,Customer Id,First Name,Last Name,Company,City,Country,Phone 1,Phone 2,Email,Subscription Date,Website'>
